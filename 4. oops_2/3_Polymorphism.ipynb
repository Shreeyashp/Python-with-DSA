# %% [markdown]
# Below problem is for reference from previous notebook

# %%
class Vehicle:
  def __init__(self, color, maxspeed):
    self.color = color
    self.__maxspeed = maxspeed

  def getmaxspeed(self):
    return self.__maxspeed

  def setmaxspeed(self, maxspeed):
    self.__maxspeed = maxspeed

  def print(self):
    print("color: ", self.color)
    print("maxspeed: ", self.getmaxspeed())

class carVehicle(Vehicle):
  def __init__(self, color, maxspeed, numGears, isConvertible):
    super().__init__(color, maxspeed)
    self.numGears = numGears
    self.isConvertible = isConvertible
    
  def printcar(self):
    super().print()
    # self.print()  you can use self.print instead of super().
    print("numGears: ", self.numGears)
    print("isConvertible: ", self.isConvertible)

# %%
c = carVehicle("red", 15, 3, False)

# %%
c.printcar()
# Out:
# color:  red
# maxspeed:  15
# numGears:  3
# isConvertible:  False

# %% [markdown]
# #### **Polymorphism**

# %%
class Vehicle:
  def __init__(self, color, maxspeed):
    self.color = color
    self.__maxspeed = maxspeed

  def getmaxspeed(self):
    return self.__maxspeed

  def setmaxspeed(self, maxspeed):
    self.__maxspeed = maxspeed

  def print(self):
    print("color: ", self.color)
    print("maxspeed: ", self.getmaxspeed())

class car(Vehicle):
  def __init__(self, color, maxspeed, numGears, isConvertible):
    super().__init__(color, maxspeed)
    self.numGears = numGears
    self.isConvertible = isConvertible
    
  def print(self):
    # super().print()
    # self.print()  you can use self.print instead of super().
    print("numGears: ", self.numGears)
    print("isConvertible: ", self.isConvertible)

# %%
c = car("red", 15, 3, False)
c.print()
# Out:
# numGears:  3
# isConvertible:  False

# %% [markdown]
# ![MicrosoftTeams-image.png](data:image/png;base64,...)

# %%
class Vehicle:
  def __init__(self, color, maxspeed):
    self.color = color
    self.__maxspeed = maxspeed

  def getmaxspeed(self):
    return self.__maxspeed

  def setmaxspeed(self, maxspeed):
    self.__maxspeed = maxspeed

  def print(self):
    print("color: ", self.color)
    print("maxspeed: ", self.getmaxspeed())

class car(Vehicle):
  def __init__(self, color, maxspeed, numGears, isConvertible):
    super().__init__(color, maxspeed)
    self.numGears = numGears
    self.isConvertible = isConvertible
    
  # def print(self):
  #   # super().print()
  #   # self.print()  you can use self.print instead of super().
  #   print("numGears: ", self.numGears)
  #   print("isConvertible: ", self.isConvertible)

# %%
c = car("red", 15, 3, False)
c.print()
# Out:
# color:  red
# maxspeed:  15

# %% [markdown]
# By commenting out (def print) now car will give o/p of Vehicle- print
