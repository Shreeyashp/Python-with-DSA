# %% [markdown]
# ![MicrosoftTeams-image (1).png](data:image/png;base64,...)

# %% [markdown]
# ![MicrosoftTeams-image (2).png](data:image/png;base64,...)

# %%
def binarysearch(a, x, si, ei):
  if si>ei:
    return -1

  mid = (si+ei)//2
  if a[mid]==x:
    return mid

  elif a[mid] > x:
    return binarysearch(a, x, si, mid-1)

  else:
    return binarysearch(a, x, mid+1, ei)

# %% [markdown]
# ![MicrosoftTeams-image (3).png](data:image/png;base64,...)

# %%
binarysearch([1,3,5,7,9,11,13,15,16,17], 19, 0, 9)
# Out:
# -1

# %%
binarysearch([1,3,5,7,9,11,13,15,16,17], 3, 0, 9)
# Out:
# 1

# %% [markdown]
# ![MicrosoftTeams-image (5).png](data:image/png;base64,...)
